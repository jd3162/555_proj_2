# %%
import random
from textworld_express import TextWorldExpressEnv

# Initialize game generator
env = TextWorldExpressEnv(envStepLimit=50)

# Set the game generator to generate a particular game (cookingworld, twc, or coin)
env.load(gameName="cookingworld", gameParams="numLocations=3,includeDoors=1")

# Then, randomly generate and play 10 games within the defined parameters
for episode_id in range(1):
  # First step
  obs, infos = env.reset(seed=episode_id, gameFold="train", generateGoldPath=True)

  # Display the observations from the environment.
  print(obs)

  for step_id in range(0, 50):
    # Select a random valid action
    validActions = sorted(infos['validActions'])
    randomAction = random.choice(validActions)

    # Take that action
    obs, reward, done, infos = env.step(randomAction)

    # Display action and the game's feedback.
    print(">", randomAction)
    print(obs, reward)
# Out:
# You are in the kitchen. In one part of the room you see a stove. There is also an oven. You also see a fridge that is closed. In another part of the room you see a counter that has a knife, a red apple, a green hot pepper, a banana, and a cookbook on it. In one part of the room you see a kitchen cupboard that is closed. There is also a cutlery drawer that is closed. You also see a trash can that is closed. In another part of the room you see a dishwasher that is closed. In one part of the room you see a dining chair, that has nothing on it.
# To the South you see a closed screen door. To the East you see a closed plain door.
# > examine kitchen cupboard
# a kitchen cupboard that is closed 0.0
# > open trash can
# You open the trash can. It's empty inside. 0.0
# > open cutlery drawer
# You open the cutlery drawer. It's empty inside. 0.0
# > examine oven
# an oven 0.0
# > examine dishwasher
# a dishwasher that is closed 0.0
# > examine cutlery drawer
# an open cutlery drawer, that is empty 0.0
# > examine trash can
# an open trash can, that is empty 0.0
# > examine dining chair
# a dining chair, that has nothing on it 0.0
# > examine cookbook
# Gather all following ingredients and follow the directions to prepare this tasty meal.
#
# Ingredients:
#   block of cheese
#   red apple
#   white onion
#
# Directions:
#   chop the block of cheese
#   grill the block of cheese
#   dice the red apple
#   grill the red apple
#   grill the white onion
#   prepare meal
#
#  0.0
# > take banana
# You take the banana. 0.0
# > read cookbook
# Gather all following ingredients and follow the directions to prepare this tasty meal.
#
# Ingredients:
#   block of cheese
#   red apple
#   white onion
#
# Directions:
#   chop the block of cheese
#   grill the block of cheese
#   dice the red apple
#   grill the red apple
#   grill the white onion
#   prepare meal
#
#  0.0
# > inventory
# Inventory (maximum capacity is 5 items):
#   a banana
#  0.0
# > examine banana
# a banana 0.0
# > cook banana in oven
# You roast the banana with the oven. 0.0
# > examine kitchen cupboard
# a kitchen cupboard that is closed 0.0
# > open door to south
# You open the screen door, revealing the backyard.  0.0
# > take red apple
# You take the red apple. 0.1
# > take cookbook
# You take the cookbook. 0.0
# > examine green hot pepper
# a green hot pepper 0.0
# > cook red apple in stove
# You fry the red apple with the stove. 0.0
# > examine stove
# a stove 0.0
# > examine oven
# an oven 0.0
# > examine cookbook
# Gather all following ingredients and follow the directions to prepare this tasty meal.
#
# Ingredients:
#   block of cheese
#   red apple
#   white onion
#
# Directions:
#   chop the block of cheese
#   grill the block of cheese
#   dice the red apple
#   grill the red apple
#   grill the white onion
#   prepare meal
#
#  0.0
# > put cookbook in counter
# You put the cookbook in the counter. 0.0
# > close cutlery drawer
# You close the cutlery drawer. 0.0
# > examine cutlery drawer
# a cutlery drawer that is closed 0.0
# > examine banana
# a roasted banana 0.0
# > look around
# You are in the kitchen. In one part of the room you see a stove. There is also an oven. You also see a fridge that is closed. In another part of the room you see a counter that has a knife, a green hot pepper, and a cookbook on it. In one part of the room you see a kitchen cupboard that is closed. There is also a cutlery drawer that is closed. You also see an open trash can, that is empty. In another part of the room you see a dishwasher that is closed. In one part of the room you see a dining chair, that has nothing on it.
# Through an open screen door, to the South you see the backyard. To the East you see a closed plain door.  0.0
# > close door to south
# You close the screen door to the backyard.  0.0
# > move south
# You can't move there, the door is closed.  0.0
# > close trash can
# You close the trash can. 0.0
# > examine counter
# a counter that has a knife, a green hot pepper, and a cookbook on it 0.0
# > examine cookbook
# Gather all following ingredients and follow the directions to prepare this tasty meal.
#
# Ingredients:
#   block of cheese
#   red apple
#   white onion
#
# Directions:
#   chop the block of cheese
#   grill the block of cheese
#   dice the red apple
#   grill the red apple
#   grill the white onion
#   prepare meal
#
#  0.0
# > examine oven
# an oven 0.0
# > take cookbook
# You take the cookbook. 0.0
# > read cookbook
# Gather all following ingredients and follow the directions to prepare this tasty meal.
#
# Ingredients:
#   block of cheese
#   red apple
#   white onion
#
# Directions:
#   chop the block of cheese
#   grill the block of cheese
#   dice the red apple
#   grill the red apple
#   grill the white onion
#   prepare meal
#
#  0.0
# > put cookbook in dining chair
# You put the cookbook in the dining chair. 0.0
# > examine green hot pepper
# a green hot pepper 0.0
# > examine counter
# a counter that has a knife, and a green hot pepper on it 0.0
# > open trash can
# You open the trash can. It's empty inside. 0.0
# > move east
# You can't move there, the door is closed.  0.0
# > examine cutlery drawer
# a cutlery drawer that is closed 0.0
# > examine oven
# an oven 0.0
# > examine dining chair
# a dining chair that has a cookbook on it 0.0
# > examine green hot pepper
# a green hot pepper 0.0
# > close door to south
# That is already closed.  0.0
# > close trash can
# You close the trash can. 0.0
# > close door to east
# That is already closed.  0.0
# > examine cutlery drawer
# a cutlery drawer that is closed 0.0
# > open kitchen cupboard
# You open the kitchen cupboard. It's empty inside. 0.0
